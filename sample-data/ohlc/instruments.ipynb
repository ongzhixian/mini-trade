# %%
import json
import pandas as pd

# %%
#pd.read_json('C:/src/github.com/ongzhixian/mini-trade/sample-data/ohlc/xau_usd.json')
data = pd.read_json('./instruments.json')

with open('./instruments.json') as in_file:
    data = json.load(in_file)
 
instruments_df = pd.DataFrame(data['instruments'])

# %%
#json.load('C:/src/github.com/ongzhixian/mini-trade/sample-data/ohlc/instruments.json')
instruments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   name                                     127 non-null    object
#  1   type                                     127 non-null    object
#  2   displayName                              127 non-null    object
#  3   pipLocation                              127 non-null    int64
#  4   displayPrecision                         127 non-null    int64
#  5   tradeUnitsPrecision                      127 non-null    int64
#  6   minimumTradeSize                         127 non-null    object
#  7   maximumTrailingStopDistance              127 non-null    object
#  8   minimumTrailingStopDistance              127 non-null    object
#  9   maximumPositionSize                      127 non-null    object
# ...

# %%
instruments_df
# Out:
#            name      type      displayName  pipLocation  displayPrecision  \
# 0    NATGAS_USD       CFD      Natural Gas           -2                 3
# 1    US2000_USD       CFD     US Russ 2000           -2                 3
# 2      DE30_EUR       CFD       Germany 30            0                 1
# 3       HKD_JPY  CURRENCY          HKD/JPY           -4                 5
# 4       EUR_CAD  CURRENCY          EUR/CAD           -4                 5
# ..          ...       ...              ...          ...               ...
# 122     EUR_AUD  CURRENCY          EUR/AUD           -4                 5
# 123     XAG_GBP     METAL       Silver/GBP           -4                 5
# 124     XAU_XAG     METAL      Gold/Silver           -2                 3
# 125     CAD_JPY  CURRENCY          CAD/JPY           -2                 3
# 126     BCO_USD       CFD  Brent Crude Oil           -2                 3
#
#      tradeUnitsPrecision minimumTradeSize maximumTrailingStopDistance  \
# ...

# %%
pd.set_option('display.max_rows', None)

instruments_df[ ['name', 'type', 'displayName'] ].sort_values(['type', 'name'])
# Out:
#            name      type      displayName
# 23    AU200_AUD       CFD    Australia 200
# 28      BCH_USD       CFD     Bitcoin Cash
# 126     BCO_USD       CFD  Brent Crude Oil
# 52      BTC_USD       CFD          Bitcoin
# 26     CH20_CHF       CFD   Switzerland 20
# 7    CHINAH_HKD       CFD   China H Shares
# 95     CN50_USD       CFD        China A50
# 22     CORN_USD       CFD             Corn
# 85   DE10YB_EUR       CFD             Bund
# 2      DE30_EUR       CFD       Germany 30
# 34    ESPIX_EUR       CFD         Spain 35
# 56      ETH_USD       CFD            Ether
# 117    EU50_EUR       CFD        Europe 50
# 61     FR40_EUR       CFD        France 40
# 113    HK33_HKD       CFD     Hong Kong 33
# 98   JP225Y_JPY       CFD  Japan 225 (JPY)
# 60    JP225_USD       CFD        Japan 225
# 112     LTC_USD       CFD         Litecoin
# 8    NAS100_USD       CFD       US Nas 100
# 0    NATGAS_USD       CFD      Natural Gas
# 18     NL25_EUR       CFD   Netherlands 25
# ...
